# %%
my_data = [
    {'species': 'clean', 'FID': 157.667513},
    {'species': 'clean', 'FID': 141},
    {'species': 'clean', 'FID': 200.59},
    {'species': 'clean', 'FID': 117.297346},
    {'species': 'clean', 'FID': 160.825393},
    {'species': 'clean', 'FID': 185.435611},
    {'species': 'clean', 'FID': 98.1830071},
    {'species': 'clean', 'FID': 126.278123},
    {'species': 'clean', 'FID': 169.746313},
    {'species': 'clean', 'FID': 102.090723},
    {'species': 'clean', 'FID': 103.822754},
    {'species': 'clean', 'FID': 168.632979},
    {'species': 'clean', 'FID': 177.983},
    {'species': 'clean', 'FID': 119.299},
    {'species': 'clean', 'FID': 66.86},

    {'species': 'eps-6-255', 'FID': 438.6445543},
    {'species': 'eps-6-255', 'FID': 350.0159003},
    {'species': 'eps-6-255', 'FID': 262.0860997},
    {'species': 'eps-6-255', 'FID': 347.7821328},
    {'species': 'eps-6-255', 'FID': 249.1987801},
    {'species': 'eps-6-255', 'FID': 307.422671},
    {'species': 'eps-6-255', 'FID': 333.475482},
    {'species': 'eps-6-255', 'FID': 299.8271528},
    {'species': 'eps-6-255', 'FID': 345.2815569},
    {'species': 'eps-6-255', 'FID': 240.4149993},
    {'species': 'eps-6-255', 'FID': 375.514924},
    {'species': 'eps-6-255', 'FID': 249.0957174},
    {'species': 'eps-6-255', 'FID': 292.14573},
    {'species': 'eps-6-255', 'FID': 308.1906192},
    {'species': 'eps-6-255', 'FID': 313.8523717},

    {'species': 'eps-8-255', 'FID': 392.8330741},
    {'species': 'eps-8-255', 'FID': 287.409749},
    {'species': 'eps-8-255', 'FID': 456.3931092},
    {'species': 'eps-8-255', 'FID': 249.8088113},
    {'species': 'eps-8-255', 'FID': 362.1648711},
    {'species': 'eps-8-255', 'FID': 323.707472},
    {'species': 'eps-8-255', 'FID': 415.1033162},
    {'species': 'eps-8-255', 'FID': 318.0762992},
    {'species': 'eps-8-255', 'FID': 444.3747103},
    {'species': 'eps-8-255', 'FID': 234.3326337},
    {'species': 'eps-8-255', 'FID': 216.1048712},
    {'species': 'eps-8-255', 'FID': 449.1264019},
    {'species': 'eps-8-255', 'FID': 404.0402574},
    {'species': 'eps-8-255', 'FID': 287.3215753},
    {'species': 'eps-8-255', 'FID': 317.0092666},

    {'species': 'eps-12-255', 'FID': 325.040745},
    {'species': 'eps-12-255', 'FID': 522.345404},
    {'species': 'eps-12-255', 'FID': 466.211349},
    {'species': 'eps-12-255', 'FID': 400.7606},
    {'species': 'eps-12-255', 'FID': 350.453},
    {'species': 'eps-12-255', 'FID': 374.572029},
    {'species': 'eps-12-255', 'FID': 291.616701},
    {'species': 'eps-12-255', 'FID': 320.444633},
    {'species': 'eps-12-255', 'FID': 274.12363},
    {'species': 'eps-12-255', 'FID': 474.837749},
    {'species': 'eps-12-255', 'FID': 275.15044},
    {'species': 'eps-12-255', 'FID': 379.018364},
    {'species': 'eps-12-255', 'FID': 399.6735722},
    {'species': 'eps-12-255', 'FID': 357.936994},
    {'species': 'eps-12-255', 'FID': 260.4675},

]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 将列表转换为DataFrame
my_data_df = pd.DataFrame(my_data)

# 绘制小提琴图
plt.figure(figsize=(10, 6))
sns.violinplot(data=my_data_df, x='species', y='FID', palette='Set1')

# 设置标题和坐标轴标签
plt.title('Comparison')
plt.xlabel('Methods')
plt.ylabel('BRIS Score')

# 设置x轴和y轴字体大小
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# 显示图形
plt.show()
# Out:
# /tmp/ipykernel_3814848/402984694.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=my_data_df, x='species', y='FID', palette='Set1')

# %%
python evaluations/ism_fdfr.py  --emb_dirs /root/2d-cfs-nj/alllanguo/code/SDXL/datasets/celeba/158 --data_dir /root/2d-cfs-nj/alllanguo/code/SDXL/infer/0424/158-iwanti170_raw

# %%
python evaluations/brisques.py --prompt_path /root/2d-cfs-nj/alllanguo/code/SDXL/infer/0424/158-iwadvdm170_raw

# %%
python evaluations/ism_fdfr.py   --data_dir /root/2d-cfs-nj/alllanguo/code/SDXL/infer/0424/177-gam170_raw --emb_dirs /root/2d-cfs-nj/alllanguo/code/SDXL/datasets/celeba/177

# %%
/root/2d-cfs-nj/alllanguo/code/SDXL/datasets/celeba/177

# %% [markdown]
# 158:
# gam: 0.5, 0.442;
# 0.8; 0.232
#
#
# adv:
# 1, 0
# 1, 0
#
#
# anti:
# 0.7 0.139
# 1, 0
#
#
#
# 177:
# gam:
# adv:
# anti:
